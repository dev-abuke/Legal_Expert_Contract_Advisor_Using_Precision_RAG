# %% [markdown]
# # RAPTOR: Recursive Abstractive Processing for Tree-Organized Retrieval

# %%
# NOTE: An OpenAI API key must be set here for application initialization, even if not in use.
# If you're not utilizing OpenAI models, assign a placeholder string (e.g., "not_used").
import os
os.getcwd()
# Out:
# '/teamspace/studios/this_studio/Legal_Expert_Contract_Advisor_Using_Precision_RAG/raptor'

# %%
os.chdir('..')
os.getcwd()
# Out:
# '/teamspace/studios/this_studio/Legal_Expert_Contract_Advisor_Using_Precision_RAG'

# %%
import docx2txt

# extract text
text = docx2txt.process("data/raw/docx/Raptor Contract.docx")

# Save the text to a file
with open('data/raw/txt/raptor.txt', 'w') as f:
    f.write(text)

# %%
import docx2txt

# extract text
text2 = docx2txt.process("data/raw/docx/Robinson Advisory.docx")

# Save the text to a file
with open('data/raw/txt/robinson.txt', 'w') as f:
    f.write(text2)

# %%
#  merge text and text2
text = text + text2

# %%
text
# Out:
# '[R&G Draft 12.__.2021]\n\n\t\t \n\n\t\t \n\n\n\n\n\n\n\nSTOCK PURCHASE AGREEMENT\n\nBY AND AMONG\n\n[BUYER],\n\n[TARGET COMPANY],\n\nTHE SELLERS LISTED ON SCHEDULE I HERETO\n\nAND\n\nTHE SELLERS’ REPRESENTATIVE NAMED HEREIN\n\nDated as of [●]\n\n\n\n[This document is intended solely to facilitate discussions among the parties identified herein.  Neither this document nor such discussions are intended to create, nor will either or both be deemed to create, a legally binding or enforceable offer or agreement of any type or nature, unless and until a definitive written agreement is executed and delivered by each of the parties hereto.\n\n\n\nThis document shall be kept confidential pursuant to the terms of the Confidentiality Agreement entered into by the parties and, if applicable, its affiliates with respect to the subject matter hereof.]\n\n\n\n\n\nTABLE OF CONTENTS\n\n\tARTICLE I DEFINITIONS; CERTAIN RULES OF CONSTRUCTION\t2\n\n\t\tSection 1.01\tDefinitions\t2\n\n\t\tSection 1.02\tCertain Matters of Construction\t13\n\n\tARTICLE II PURCHASE AND SALE OF SHARES AND WARRANTS; TREATMENT OF OPTIONS; CLOSING.\t14\n\n\t\tSection 2.01\tPurchase and Sale of Shares\t14\n\n\t\tSection 2.02\tPurchase Price\t14\n\n\t\tSection 2.03\tThe Closing\t14\n\n\t\tSection 2.04\tClosing Payments.\t15\n\n\t\tSection 2.05\tClosing Deliveries\t15\n\n\t\tSection 2.06\tTreatment of Options\t16\n\n\t\tSection 2.07\tPurchase Price Adjustment\t17\n\n\t\tSection 2.08\tEscrow\t19\n\n\tARTICLE III REPRESENTATIONS AND WARRANTIES REGARDING THE ACQUIRED COMPANIES.\t19\n\n\t\tSection 3.01\tOrganization\t19\n\n\t\tSection 3.02\tPower and Authorization\t20\n\n\t\tSection 3.03\tAuthorization of Governmental Authorities\t20\n\n\t\tSection 3.04\tNoncontravention\t20\n\n\t\tSection 3.05\tCapitalization of the Acquired Companies\t21\n\n\t\tSection 3.06\tFinancial Matters\t22\n\n\t\tSection 3.07\tAbsence of Certain Developments\t22\n\n\t\tSection 3.08\tDebt; Guarantees\t24\n\n\t\tSection 3.09\tAssets\t25\n\n\t\tSection 3.10\tReal Property\t25\n\n\t\tSection 3.11\tIntellectual Property\t26\n\n\t\tSection 3.12\tLegal Compliance; Illegal Payments; Permits\t29\n\n\t\tSection 3.13\tTax Matters\t30\n\n\t\tSection 3.14\tEmployee Benefit Plans\t32\n\n\t\tSection 3.15\tEnvironmental Matters\t33\n\n\t\tSection 3.16\tContracts\t34\n\n\t\tSection 3.17\tRelated Party Transactions\t36\n\n\t\tSection 3.18\tCustomers and Suppliers\t37\n\n\t\tSection 3.19\tLabor Matters\t37\n\n\t\tSection 3.20\tLitigation; Government Orders\t37\n\n\t\tSection 3.21\tInsurance\t38\n\n\t\tSection 3.22\tNo Brokers\t38\n\n\t\tSection 3.23\tFull Disclosure\t38\n\n\tARTICLE IV INDIVIDUAL REPRESENTATIONS AND WARRANTIES OF THE SELLERS.\t38\n\n\t\tSection 4.01\tOrganization\t39\n\n\t\tSection 4.02\tPower and Authorization\t39\n\n\t\tSection 4.03\tAuthorization of Governmental Authorities\t39\n\n\t\tSection 4.04\tNoncontravention\t39\n\n\t\tSection 4.05\tTitle\t39\n\n\t\tSection 4.06\tNo Brokers\t40\n\n\tARTICLE V REPRESENTATIONS AND WARRANTIES OF THE BUYER.\t40\n\n\t\tSection 5.01\tOrganization\t40\n\n\t\tSection 5.02\tPower and Authorization\t40\n\n\t\tSection 5.03\tAuthorization of Governmental Authorities\t40\n\n\t\tSection 5.04\tNoncontravention\t40\n\n\t\tSection 5.05\tNo Brokers\t41\n\n\tARTICLE VI COVENANTS OF THE PARTIES\t41\n\n\t\tSection 6.01\tExpenses\t41\n\n\t\tSection 6.02\tConfidentiality\t41\n\n\t\tSection 6.03\tPublicity\t42\n\n\t\tSection 6.04\tRelease.\t42\n\n\t\tSection 6.06\tD&O Tail.\t43\n\n\t\tSection 6.07\tFurther Assurances\t43\n\n\tARTICLE VII TAX MATTERS\t43\n\n\t\tSection 7.01\tTax Sharing Agreements\t43\n\n\t\tSection 7.02\tCertain Taxes and Fees\t43\n\n\t\tSection 7.03\tCooperation on Tax Matters\t44\n\n\tARTICLE VIII SURVIVAL; RECOURSE LIMITATIONS\t44\n\n\t\tSection 8.01\tSurvival\t44\n\n\t\tSection 8.02\tRecourse Limitations.\t44\n\n\tARTICLE IX  MISCELLANEOUS\t45\n\n\t\tSection 9.01\tNotices\t45\n\n\t\tSection 9.02\tSuccession and Assignment; No Third-Party Beneficiaries\t46\n\n\t\t ...

# %%
# Cinderella story defined in sample.txt
with open('data/raw/txt/raptor.txt', 'r') as file:
    text = file.read()

# print the last 1000 characters
print(text[-2000:])
# Out:
# vileged Communications.  NBA has acted as counsel for the Company Securityholders for various matters prior to the Closing, including in connection with this Agreement and the Ancillary Agreements, the negotiation and documentation of this Agreement and the Ancillary Agreements, and the consummation of the Contemplated Transactions (collectively, the “Pre-Closing Engagements”).  Each Party agrees that (a) all communications in any form or format whatsoever between or among NBA, on the one hand, and the Company and the Company Securityholders, or any of their Representatives, on the other hand, that relate in any way to the Pre-Closing Engagements (collectively, the “Privileged Communications”) will be deemed to be attorney-client privileged, (b) neither this Agreement nor any of the other Ancillary Agreement shall effect any transfer of any right, title, or interest in the Privileged Communications to the Buyer or any Acquired Company (c) the Privileged Communications and the expectation of client confidence relating thereto shall belong solely to Company Securityholders and may be controlled solely by the Sellers’ Representative and shall not pass to or be claimed by any other Party, and (d) NBA shall have no duty whatsoever to reveal or disclose any such Privileged Communications, or any of its files relating to the Pre-Closing Engagements, to any Party other than the Sellers and the Sellers’ Representative.
#
#
#
#
#
#
#
# [Remainder of page intentionally left blank; Signature pages follow]
#
#
#
#
#
# IN WITNESS WHEREOF, each of the undersigned has executed this Stock Purchase Agreement as of the date first above written.
#
# 	BUYER:	[buyer]
#
#
# By:___________________________________
# 	Name:
# 	Title:
#
# 	THE COMPANY:	[Company]
#
#
# By:___________________________________
# 	Name:
# 	Title:
#
# 	SELLERS’ REPRESENTATIVE:	[SELLERS’ REPRESENTATIVE]
#
#
# By:___________________________________
# 	Name:
# 	Title:
#
# 	THE SELLERS:		[●]
#
#
#
#
#
#
#
# 112923184_5
#
# 112923184_5
#
# 		-iv-
#
# 112923184_5
#
#
#
#
#
# 		-16-
#
# 112923184_5

# %% [markdown]
# 1) **Building**: RAPTOR recursively embeds, clusters, and summarizes chunks of text to construct a tree with varying levels of summarization from the bottom up. You can create a tree from the text in 'sample.txt' using `RA.add_documents(text)`.
#
# 2) **Querying**: At inference time, the RAPTOR model retrieves information from this tree, integrating data across lengthy documents at different abstraction levels. You can perform queries on the tree with `RA.answer_question`.

# %% [markdown]
# ### Building the tree

# %%
from raptor import RetrievalAugmentation
# Out:
# 2024-07-07 10:30:01,288 - Loading faiss with AVX512 support.
# 2024-07-07 10:30:01,311 - Successfully loaded faiss with AVX512 support.

# %%
RA = RetrievalAugmentation()

# construct the tree
RA.add_documents(text)
# Out:
# 2024-07-07 10:30:03,765 - Successfully initialized TreeBuilder with Config
#         TreeBuilderConfig:
#             Tokenizer: <Encoding 'cl100k_base'>
#             Max Tokens: 100
#             Num Layers: 5
#             Threshold: 0.5
#             Top K: 5
#             Selection Mode: top_k
#             Summarization Length: 100
#             Summarization Model: <raptor.SummarizationModels.GPT3TurboSummarizationModel object at 0x7f1935e738b0>
#             Embedding Models: {'OpenAI': <raptor.EmbeddingModels.OpenAIEmbeddingModel object at 0x7f1935e73910>}
#             Cluster Embedding Model: OpenAI
#
#         Reduction Dimension: 10
#         Clustering Algorithm: RAPTOR_Clustering
#         Clustering Parameters: {}
#
# 2024-07-07 10:30:03,766 - Successfully initialized ClusterTreeBuilder with Config
#         TreeBuilderConfig:
#             Tokenizer: <Encoding 'cl100k_base'>
#             Max Tokens: 100
#             Num Layers: 5
#             Threshold: 0.5
#             Top K: 5
#             Selection Mode: top_k
#             Summarization Length: 100
#             Summarization Model: <raptor.SummarizationModels.GPT3TurboSummarizationModel object at 0x7f1935e738b0>
#             Embedding Models: {'OpenAI': <raptor.EmbeddingModels.OpenAIEmbeddingModel object at 0x7f1935e73910>}
#             Cluster Embedding Model: OpenAI
#
#         Reduction Dimension: 10
#         Clustering Algorithm: RAPTOR_Clustering
#         Clustering Parameters: {}
#
# 2024-07-07 10:30:03,767 - Successfully initialized RetrievalAugmentation with Config
#         RetrievalAugmentationConfig:
#
#         TreeBuilderConfig:
#             Tokenizer: <Encoding 'cl100k_base'>
#             Max Tokens: 100
#             Num Layers: 5
#             Threshold: 0.5
#             Top K: 5
#             Selection Mode: top_k
#             Summarization Length: 100
#             Summarization Model: <raptor.SummarizationModels.GPT3TurboSummarizationModel object at 0x7f1935e738b0>
#             Embedding Models: {'OpenAI': <raptor.EmbeddingModels.OpenAIEmbeddingModel object at 0x7f1935e73910>}
#             Cluster Embedding Model: OpenAI
#
#         Reduction Dimension: 10
#         Clustering Algorithm: RAPTOR_Clustering
#         Clustering Parameters: {}
#
#
#
#         TreeRetrieverConfig:
#             Tokenizer: <Encoding 'cl100k_base'>
#             Threshold: 0.5
#             Top K: 5
#             Selection Mode: top_k
#             Context Embedding Model: OpenAI
#             Embedding Model: <raptor.EmbeddingModels.OpenAIEmbeddingModel object at 0x7f1935ec86d0>
#             Num Layers: None
#             Start Layer: None
#
#
#             QA Model: <raptor.QAModels.GPT3TurboQAModel object at 0x7f1935ede980>
#             Tree Builder Type: cluster
#
# 2024-07-07 10:30:03,885 - Creating Leaf Nodes
# 2024-07-07 10:30:04,002 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:04,004 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:04,006 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:04,007 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:04,016 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:04,028 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:04,033 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:04,036 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:04,129 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:04,144 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:04,243 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:04,263 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:04,302 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:04,517 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:04,537 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:04,601 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:04,635 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:04,870 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:05,026 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:05,202 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:05,416 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:05,498 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:06,013 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:06,015 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:06,478 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:06,507 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:06,526 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:07,319 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:08,151 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:08,382 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:08,559 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:08,877 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:09,184 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:09,200 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:09,283 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:10,326 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:10,395 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:10,948 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:11,852 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:12,797 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:12,871 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:12,969 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:14,716 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:15,094 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:16,585 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:18,535 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:18,594 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:18,843 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:18,897 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:19,227 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:19,692 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:20,173 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:20,234 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:21,067 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:22,203 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:22,439 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:22,497 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:22,821 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:22,878 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:24,815 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:25,374 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:25,440 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:25,591 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:25,929 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:25,962 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:26,036 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:26,250 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:26,814 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:27,228 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:27,888 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:27,952 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:28,390 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:28,560 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:28,780 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:28,958 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:29,416 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:29,557 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:30,704 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:31,535 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:31,589 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:32,112 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:33,425 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:33,708 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:34,149 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:34,211 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:34,552 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:34,687 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:34,907 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:35,272 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:36,380 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:36,426 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:36,443 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:36,498 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:36,544 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:36,600 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:36,710 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:37,099 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:37,136 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:37,228 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:37,233 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:38,768 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:39,475 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:40,655 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:41,221 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:41,278 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:41,527 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:42,105 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:42,164 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:42,252 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:42,328 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:42,395 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:43,046 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:43,114 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:43,443 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:43,795 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:44,033 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:44,298 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:44,625 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:45,371 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:45,427 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:45,466 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:45,529 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:45,745 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:46,205 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:47,567 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:48,274 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:48,332 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:48,385 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:48,522 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:48,984 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:49,248 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:49,784 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:50,596 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:53,102 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:53,111 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:53,164 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:53,773 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:54,208 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:54,267 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:54,752 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:54,943 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:55,528 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:56,642 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:56,758 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:56,978 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:57,044 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:57,594 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:57,822 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:57,879 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:57,881 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:58,152 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:58,933 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:58,988 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:59,008 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:30:59,463 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:00,047 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:00,156 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:00,198 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:00,642 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:01,634 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:02,554 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:02,611 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:02,690 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:03,132 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:03,371 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:03,456 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:03,845 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:04,008 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:04,068 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:04,153 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:04,683 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:05,210 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:05,467 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:05,701 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:06,290 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:07,039 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:07,573 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:07,638 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:08,136 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:09,199 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:09,255 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:09,313 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:09,568 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:09,848 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:09,945 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:10,538 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:11,066 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:11,530 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:11,592 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:12,570 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:12,574 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:13,056 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:13,118 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:14,094 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:14,332 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:14,395 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:14,451 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:14,674 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:14,726 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:15,017 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:15,137 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:15,193 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:15,270 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:15,272 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:15,415 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:16,549 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:16,609 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:16,997 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:17,040 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:17,098 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:17,372 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:17,427 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:17,428 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:18,122 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:18,340 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:18,895 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:18,959 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:19,002 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:19,014 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:19,284 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:19,418 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:19,999 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:20,313 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:20,552 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:21,115 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:22,103 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:23,287 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:23,408 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:23,615 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:23,832 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:23,883 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:23,887 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:24,050 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:24,111 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:24,650 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:24,696 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:24,754 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:24,925 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:25,050 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:25,063 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:25,132 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:25,277 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:25,334 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:25,341 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:25,700 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:25,971 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:26,132 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:26,210 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:26,864 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:26,975 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:27,285 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:27,358 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:27,501 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:27,827 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:27,935 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:28,293 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:28,713 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:29,131 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:29,193 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:29,319 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:29,592 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:29,668 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:29,813 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:29,853 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:30,015 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:30,022 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:30,209 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:30,626 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:30,735 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:30,962 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:31,017 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:31,178 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:32,428 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:32,459 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:32,679 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:33,541 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:33,603 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:34,668 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:35,450 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:35,508 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:36,184 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:36,367 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:37,478 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:37,976 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:38,040 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:38,286 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:38,608 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:38,654 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:38,665 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:38,711 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:39,145 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:39,361 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:39,445 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:39,502 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:39,561 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:39,613 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:39,629 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:39,709 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:40,400 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:40,810 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:40,879 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:41,028 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:41,171 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:41,263 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:42,198 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:42,634 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:42,696 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:44,181 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:44,211 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:44,267 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:44,331 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:44,491 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:44,645 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:44,817 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:45,582 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:45,694 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:45,756 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:46,667 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:46,699 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:46,763 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:47,052 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:47,542 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:47,572 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:47,762 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:48,214 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:48,414 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:48,649 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:48,966 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:49,024 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:49,622 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:49,682 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:50,113 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:50,178 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:50,508 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:51,921 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:52,014 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:52,075 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:52,315 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:52,507 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:52,580 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:53,452 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:54,384 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:54,989 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:56,345 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:56,543 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:57,650 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:57,709 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:58,429 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:58,564 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:59,161 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:59,467 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:59,527 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:31:59,934 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:00,172 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:00,232 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:00,364 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:00,830 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:00,889 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:01,633 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:02,166 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:02,169 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:02,230 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:02,241 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:02,249 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:02,314 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:02,437 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:02,493 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:02,539 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:02,662 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:02,727 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:03,249 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:03,272 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:03,293 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:03,851 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:03,916 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:04,730 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:04,793 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:05,025 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:05,063 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:05,301 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:05,551 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:06,188 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:06,255 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:06,289 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:06,441 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:06,837 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:07,289 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:07,452 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:07,994 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:08,614 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:08,638 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:08,914 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:09,381 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:09,649 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:09,709 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:09,906 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:10,684 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:10,708 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:11,632 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:12,077 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:12,134 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:12,736 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:13,178 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:14,046 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:14,102 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:14,372 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:14,481 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:14,696 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:14,762 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:32:14,769 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# ...
#     return self(f, *args, **kw)
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/tenacity/__init__.py", line 382, in __call__
#     result = fn(*args, **kwargs)
#   File "/teamspace/studios/this_studio/Legal_Expert_Contract_Advisor_Using_Precision_RAG/raptor/raptor/EmbeddingModels.py", line 26, in create_embedding
#     self.client.embeddings.create(input=[text], model=self.model)
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/openai/resources/embeddings.py", line 105, in create
#     # numpy is not installed / base64 optimisation isn't enabled for this model yet
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/openai/_base_client.py", line 1055, in post
#     remaining_retries: int,
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/openai/_base_client.py", line 834, in request
#     version=version,
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/openai/_base_client.py", line 858, in _request
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/httpx/_client.py", line 914, in send
#     response = self._send_handling_auth(
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/httpx/_client.py", line 942, in _send_handling_auth
#     response = self._send_handling_redirects(
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/httpx/_client.py", line 979, in _send_handling_redirects
#     response = self._send_single_request(request)
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/httpx/_client.py", line 1026, in _send_single_request
#     logger.info(
# Message: 'HTTP Request: %s %s "%s %d %s"'
# Arguments: ('POST', URL('https://api.openai.com/v1/embeddings'), 'HTTP/1.1', 401, 'Unauthorized')
# 2024-07-07 10:49:18,264 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:49:18,294 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:49:18,626 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:49:19,795 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/logging/__init__.py", line 1103, in emit
#     stream.write(msg + self.terminator)
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/ipykernel/iostream.py", line 664, in write
#     self._schedule_flush()
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/ipykernel/iostream.py", line 561, in _schedule_flush
#     self.pub_thread.schedule(_schedule_in_thread)
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/ipykernel/iostream.py", line 267, in schedule
#     self._event_pipe.send(b"")
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/zmq/sugar/socket.py", line 701, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#   File "_zmq.py", line 1073, in zmq.backend.cython._zmq.Socket.send
#   File "_zmq.py", line 1115, in zmq.backend.cython._zmq.Socket.send
#   File "_zmq.py", line 1190, in zmq.backend.cython._zmq._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/threading.py", line 973, in _bootstrap
#     self._bootstrap_inner()
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/teamspace/studios/this_studio/Legal_Expert_Contract_Advisor_Using_Precision_RAG/raptor/raptor/tree_builder.py", line 175, in create_node
#     embeddings = {
#   File "/teamspace/studios/this_studio/Legal_Expert_Contract_Advisor_Using_Precision_RAG/raptor/raptor/tree_builder.py", line 176, in <dictcomp>
#     model_name: model.create_embedding(text)
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/tenacity/__init__.py", line 289, in wrapped_f
#     return self(f, *args, **kw)
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/tenacity/__init__.py", line 382, in __call__
#     result = fn(*args, **kwargs)
#   File "/teamspace/studios/this_studio/Legal_Expert_Contract_Advisor_Using_Precision_RAG/raptor/raptor/EmbeddingModels.py", line 26, in create_embedding
#     self.client.embeddings.create(input=[text], model=self.model)
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/openai/resources/embeddings.py", line 105, in create
#     # numpy is not installed / base64 optimisation isn't enabled for this model yet
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/openai/_base_client.py", line 1055, in post
#     remaining_retries: int,
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/openai/_base_client.py", line 834, in request
#     version=version,
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/openai/_base_client.py", line 858, in _request
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/httpx/_client.py", line 914, in send
#     response = self._send_handling_auth(
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/httpx/_client.py", line 942, in _send_handling_auth
#     response = self._send_handling_redirects(
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/httpx/_client.py", line 979, in _send_handling_redirects
#     response = self._send_single_request(request)
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/httpx/_client.py", line 1026, in _send_single_request
#     logger.info(
# Message: 'HTTP Request: %s %s "%s %d %s"'
# Arguments: ('POST', URL('https://api.openai.com/v1/embeddings'), 'HTTP/1.1', 401, 'Unauthorized')
# 2024-07-07 10:49:20,132 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:49:21,316 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:49:21,856 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:49:22,482 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:49:22,992 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:49:23,295 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:49:26,644 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/logging/__init__.py", line 1103, in emit
#     stream.write(msg + self.terminator)
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/ipykernel/iostream.py", line 664, in write
#     self._schedule_flush()
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/ipykernel/iostream.py", line 561, in _schedule_flush
#     self.pub_thread.schedule(_schedule_in_thread)
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/ipykernel/iostream.py", line 267, in schedule
#     self._event_pipe.send(b"")
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/zmq/sugar/socket.py", line 701, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#   File "_zmq.py", line 1073, in zmq.backend.cython._zmq.Socket.send
#   File "_zmq.py", line 1115, in zmq.backend.cython._zmq.Socket.send
#   File "_zmq.py", line 1190, in zmq.backend.cython._zmq._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/threading.py", line 973, in _bootstrap
#     self._bootstrap_inner()
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/teamspace/studios/this_studio/Legal_Expert_Contract_Advisor_Using_Precision_RAG/raptor/raptor/tree_builder.py", line 175, in create_node
#     embeddings = {
#   File "/teamspace/studios/this_studio/Legal_Expert_Contract_Advisor_Using_Precision_RAG/raptor/raptor/tree_builder.py", line 176, in <dictcomp>
#     model_name: model.create_embedding(text)
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/tenacity/__init__.py", line 289, in wrapped_f
#     return self(f, *args, **kw)
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/tenacity/__init__.py", line 382, in __call__
#     result = fn(*args, **kwargs)
#   File "/teamspace/studios/this_studio/Legal_Expert_Contract_Advisor_Using_Precision_RAG/raptor/raptor/EmbeddingModels.py", line 26, in create_embedding
#     self.client.embeddings.create(input=[text], model=self.model)
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/openai/resources/embeddings.py", line 105, in create
#     # numpy is not installed / base64 optimisation isn't enabled for this model yet
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/openai/_base_client.py", line 1055, in post
#     remaining_retries: int,
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/openai/_base_client.py", line 834, in request
#     version=version,
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/openai/_base_client.py", line 858, in _request
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/httpx/_client.py", line 914, in send
#     response = self._send_handling_auth(
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/httpx/_client.py", line 942, in _send_handling_auth
#     response = self._send_handling_redirects(
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/httpx/_client.py", line 979, in _send_handling_redirects
#     response = self._send_single_request(request)
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/httpx/_client.py", line 1026, in _send_single_request
#     logger.info(
# Message: 'HTTP Request: %s %s "%s %d %s"'
# Arguments: ('POST', URL('https://api.openai.com/v1/embeddings'), 'HTTP/1.1', 401, 'Unauthorized')
# 2024-07-07 10:49:26,719 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/logging/__init__.py", line 1104, in emit
#     self.flush()
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/logging/__init__.py", line 1084, in flush
#     self.stream.flush()
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/ipykernel/iostream.py", line 575, in flush
#     self.pub_thread.schedule(self._flush)
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/ipykernel/iostream.py", line 267, in schedule
#     self._event_pipe.send(b"")
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/zmq/sugar/socket.py", line 701, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#   File "_zmq.py", line 1073, in zmq.backend.cython._zmq.Socket.send
#   File "_zmq.py", line 1115, in zmq.backend.cython._zmq.Socket.send
#   File "_zmq.py", line 1190, in zmq.backend.cython._zmq._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/threading.py", line 973, in _bootstrap
#     self._bootstrap_inner()
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/concurrent/futures/thread.py", line 83, in _worker
#     work_item.run()
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/teamspace/studios/this_studio/Legal_Expert_Contract_Advisor_Using_Precision_RAG/raptor/raptor/tree_builder.py", line 175, in create_node
#     embeddings = {
#   File "/teamspace/studios/this_studio/Legal_Expert_Contract_Advisor_Using_Precision_RAG/raptor/raptor/tree_builder.py", line 176, in <dictcomp>
#     model_name: model.create_embedding(text)
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/tenacity/__init__.py", line 289, in wrapped_f
#     return self(f, *args, **kw)
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/tenacity/__init__.py", line 382, in __call__
#     result = fn(*args, **kwargs)
#   File "/teamspace/studios/this_studio/Legal_Expert_Contract_Advisor_Using_Precision_RAG/raptor/raptor/EmbeddingModels.py", line 26, in create_embedding
#     self.client.embeddings.create(input=[text], model=self.model)
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/openai/resources/embeddings.py", line 105, in create
#     # numpy is not installed / base64 optimisation isn't enabled for this model yet
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/openai/_base_client.py", line 1055, in post
#     remaining_retries: int,
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/openai/_base_client.py", line 834, in request
#     version=version,
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/openai/_base_client.py", line 858, in _request
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/httpx/_client.py", line 914, in send
#     response = self._send_handling_auth(
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/httpx/_client.py", line 942, in _send_handling_auth
#     response = self._send_handling_redirects(
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/httpx/_client.py", line 979, in _send_handling_redirects
#     response = self._send_single_request(request)
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/httpx/_client.py", line 1026, in _send_single_request
#     logger.info(
# Message: 'HTTP Request: %s %s "%s %d %s"'
# Arguments: ('POST', URL('https://api.openai.com/v1/embeddings'), 'HTTP/1.1', 401, 'Unauthorized')
# 2024-07-07 10:49:27,127 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:49:27,634 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:49:32,480 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:49:37,092 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"
# 2024-07-07 10:49:39,079 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 401 Unauthorized"

# %%
SAVE_PATH = "raptor_tree/robinson_contract_merged"

# %%
RA.save(SAVE_PATH)

# %%
RA = RetrievalAugmentation(tree=SAVE_PATH)
answer, context = RA.answer_question(question="What are the payments to the Advisor under the Agreement?")

# %%
answer

# %%
context

# %% [markdown]
# ### Querying from the tree
#
# ```python
# question = # any question
# RA.answer_question(question)
# ```

# %%
question = "What are the payments to the Advisor under the Agreement?"

answer = RA.answer_question(question=question)

print("Answer: ", answer)

# %%
# Save the tree by calling RA.save("path/to/save")
SAVE_PATH = "demo/cinderella"
RA.save(SAVE_PATH)

# %%
# load back the tree by passing it into RetrievalAugmentation

RA = RetrievalAugmentation(tree=SAVE_PATH)

answer = RA.answer_question(question=question)
print("Answer: ", answer)

# %% [markdown]
# ## Using other Open Source Models for Summarization/QA/Embeddings
#
# If you want to use other models such as Llama or Mistral, you can very easily define your own models and use them with RAPTOR.

# %%
import torch
from raptor import BaseSummarizationModel, BaseQAModel, BaseEmbeddingModel, RetrievalAugmentationConfig
from transformers import AutoTokenizer, pipeline

# %%
# if you want to use the Gemma, you will need to authenticate with HuggingFace, Skip this step, if you have the model already downloaded
from huggingface_hub import login
login()

# %%
from transformers import AutoTokenizer, pipeline
import torch

# You can define your own Summarization model by extending the base Summarization Class. 
class GEMMASummarizationModel(BaseSummarizationModel):
    def __init__(self, model_name="google/gemma-2b-it"):
        # Initialize the tokenizer and the pipeline for the GEMMA model
        self.tokenizer = AutoTokenizer.from_pretrained(model_name)
        self.summarization_pipeline = pipeline(
            "text-generation",
            model=model_name,
            model_kwargs={"torch_dtype": torch.bfloat16},
            device=torch.device('cuda' if torch.cuda.is_available() else 'cpu'),  # Use "cpu" if CUDA is not available
        )

    def summarize(self, context, max_tokens=150):
        # Format the prompt for summarization
        messages=[
            {"role": "user", "content": f"Write a summary of the following, including as many key details as possible: {context}:"}
        ]
        
        prompt = self.tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
        
        # Generate the summary using the pipeline
        outputs = self.summarization_pipeline(
            prompt,
            max_new_tokens=max_tokens,
            do_sample=True,
            temperature=0.7,
            top_k=50,
            top_p=0.95
        )
        
        # Extracting and returning the generated summary
        summary = outputs[0]["generated_text"].strip()
        return summary

# %%
class GEMMAQAModel(BaseQAModel):
    def __init__(self, model_name= "google/gemma-2b-it"):
        # Initialize the tokenizer and the pipeline for the model
        self.tokenizer = AutoTokenizer.from_pretrained(model_name)
        self.qa_pipeline = pipeline(
            "text-generation",
            model=model_name,
            model_kwargs={"torch_dtype": torch.bfloat16},
            device=torch.device('cuda' if torch.cuda.is_available() else 'cpu'),
        )

    def answer_question(self, context, question):
        # Apply the chat template for the context and question
        messages=[
              {"role": "user", "content": f"Given Context: {context} Give the best full answer amongst the option to question {question}"}
        ]
        prompt = self.tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
        
        # Generate the answer using the pipeline
        outputs = self.qa_pipeline(
            prompt,
            max_new_tokens=256,
            do_sample=True,
            temperature=0.7,
            top_k=50,
            top_p=0.95
        )
        
        # Extracting and returning the generated answer
        answer = outputs[0]["generated_text"][len(prompt):]
        return answer

# %%
from sentence_transformers import SentenceTransformer
class SBertEmbeddingModel(BaseEmbeddingModel):
    def __init__(self, model_name="sentence-transformers/multi-qa-mpnet-base-cos-v1"):
        self.model = SentenceTransformer(model_name)

    def create_embedding(self, text):
        return self.model.encode(text)

# %%
RAC = RetrievalAugmentationConfig(summarization_model=GEMMASummarizationModel(), qa_model=GEMMAQAModel(), embedding_model=SBertEmbeddingModel())

# %%
RA = RetrievalAugmentation(config=RAC)

# %%
with open('demo/sample.txt', 'r') as file:
    text = file.read()
    
RA.add_documents(text)

# %%
question = "How did Cinderella reach her happy ending?"

answer = RA.answer_question(question=question)

print("Answer: ", answer)
